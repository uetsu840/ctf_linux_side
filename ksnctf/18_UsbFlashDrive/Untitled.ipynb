# %%
from IPython.display import Image, display_jpeg
# png_file: str
JPEG_FILE = '[DELETED]/Liberty Leading the People.jpg'
display_jpeg(Image(JPEG_FILE))

# %%
display_jpeg(Image('image01.jpg'))

# %%
from PIL import Image

# 画像ファイルを開く
im = Image.open(JPEG_FILE)
# EXIF情報を得る
exif = im._getexif()
# 一覧で表示
for id, value in exif.items():
    print(id, value)

# %%
import numpy as np
import cv2
import os.path
TIFF_FILE = '[DELETED]/a.tiff'
if os.path.exists(TIFF_FILE):
    img = cv2.imread(TIFF_FILE)
    cv2.imshow("Lenna", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-e9853ca9aefe> in <module>()
#       6 if os.path.exists(TIFF_FILE):
#       7     img = cv2.imread(TIFF_FILE)
# ----> 8     cv2.imshow("Lenna", img)
#       9     cv2.waitKey(0)
#      10     cv2.destroyAllWindows()
#
# error: /home/travis/miniconda/conda-bld/conda_1486587069159/work/opencv-3.1.0/modules/highgui/src/window.cpp:281: error: (-215) size.width>0 && size.height>0 in function imshow
